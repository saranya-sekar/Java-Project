# %%
## Using dictionary find all the words with specific lenght for a single letter

import requests
import sys

## Retrive Dictionary data from URL
dictionary_url = "https://raw.githubusercontent.com/dwyl/english-words/master/words.txt"
dictionary_data = requests.get(dictionary_url)

## Write the dictionary data to a file
with open('C://Users//Ultimate//Desktop//Dictionary_file.txt', 'w') as file:
    file.write(dictionary_data.text)

## Read the dictionary file    
dictionary_data = open("C://Users//Ultimate//Desktop//Dictionary_file.txt","r")
dictionary_data_list = list(dictionary_data)

## Write Output to Txt File
dictionary_output_file= open("C://Users//Ultimate//Desktop//Dictionary_Same_Letter_Word.txt", "w")

## Specify the Letter You want to Search in Caps
alphabet_start_letter = "Q"
alphabet_same_start=[]

## Same letter Starting all Words List
alpha_same_word_list = [x for x in dictionary_data_list if x.lower().startswith(alphabet_start_letter.lower())]

    
## Words With Same Starting Letter with Word length as 1    
alphabet_1 = [x for x in alpha_same_word_list if len(x)==2]
dictionary_output_file.write("1 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_1:
    print(word)
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

## Words With Same Starting Letter with Word length as 2    
alphabet_2 = [x for x in alpha_same_word_list if len(x)==3]
dictionary_output_file.write("\n 2 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_2:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

## Words With Same Starting Letter with Word length as 3    
alphabet_3 = [x for x in alpha_same_word_list if len(x)==4]
dictionary_output_file.write("\n 3 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_3:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")
    
## Words With Same Starting Letter with Word length as 4
alphabet_4 = [x for x in alpha_same_word_list if len(x)==5]
dictionary_output_file.write("\n 4 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_4:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 5    
alphabet_5 = [x for x in alpha_same_word_list if len(x)==6]
dictionary_output_file.write("\n 5 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_5:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

## Words With Same Starting Letter with Word length as 6    
alphabet_6 = [x for x in alpha_same_word_list if len(x)==7]
dictionary_output_file.write("\n 6 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_6:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 7    
alphabet_7 = [x for x in alpha_same_word_list if len(x)==8]
dictionary_output_file.write("\n 7 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_7:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 8    
alphabet_8 = [x for x in alpha_same_word_list if len(x)==9]
dictionary_output_file.write("\n 8 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_8:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 9    
alphabet_9 = [x for x in alpha_same_word_list if len(x)==10]
dictionary_output_file.write("\n 9 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_9:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 10    
alphabet_10 = [x for x in alpha_same_word_list if len(x)==11]
dictionary_output_file.write("\n 10 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_10:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 11    
alphabet_11 = [x for x in alpha_same_word_list if len(x)==12]
dictionary_output_file.write("\n 11 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_11:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 12    
alphabet_12 = [x for x in alpha_same_word_list if len(x)==13]
dictionary_output_file.write("\n 12 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_12:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 13    
alphabet_13 = [x for x in alpha_same_word_list if len(x)==14]
dictionary_output_file.write("\n 13 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_13:
    dictionary_output_file.write(word)

    
## Words With Same Starting Letter with Word length as 14    
alphabet_14 = [x for x in alpha_same_word_list if len(x)==15]
dictionary_output_file.write("\n 14 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_14:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 15    
alphabet_15 = [x for x in alpha_same_word_list if len(x)==16]
dictionary_output_file.write("\n 15 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_15:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")
    
## Same letter Starting all Words List Write To Output File
dictionary_output_file.write("\n SAME LETTER STARTING ALL WORDS LIST \n")
dictionary_output_file.write("=============================== \n")
for word in alpha_same_word_list:
    print(word)
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")    
dictionary_output_file.close()  

import requests
import sys

## Retrive Dictionary data from URL
dictionary_url = "https://raw.githubusercontent.com/dwyl/english-words/master/words.txt"
dictionary_data = requests.get(dictionary_url)

## Write the dictionary data to a file
with open('C://Users//Ultimate//Desktop//Dictionary_file.txt', 'w') as file:
    file.write(dictionary_data.text)

## Read the dictionary file    
dictionary_data = open("C://Users//Ultimate//Desktop//Dictionary_file.txt","r")
dictionary_data_list = list(dictionary_data)

## Write Output to Txt File
dictionary_output_file= open("C://Users//Ultimate//Desktop//Dictionary_Same_Letter_Word.txt", "w")

## Specify the Letter You want to Search in Caps
alphabet_start_letter = "Q"
alphabet_same_start=[]

## Same letter Starting all Words List
alpha_same_word_list = [x for x in dictionary_data_list if x.lower().startswith(alphabet_start_letter.lower())]

    
## Words With Same Starting Letter with Word length as 1    
alphabet_1 = [x for x in alpha_same_word_list if len(x)==2]
dictionary_output_file.write("1 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_1:
    print(word)
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

## Words With Same Starting Letter with Word length as 2    
alphabet_2 = [x for x in alpha_same_word_list if len(x)==3]
dictionary_output_file.write("\n 2 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_2:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

## Words With Same Starting Letter with Word length as 3    
alphabet_3 = [x for x in alpha_same_word_list if len(x)==4]
dictionary_output_file.write("\n 3 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_3:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")
    
## Words With Same Starting Letter with Word length as 4
alphabet_4 = [x for x in alpha_same_word_list if len(x)==5]
dictionary_output_file.write("\n 4 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_4:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 5    
alphabet_5 = [x for x in alpha_same_word_list if len(x)==6]
dictionary_output_file.write("\n 5 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_5:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

## Words With Same Starting Letter with Word length as 6    
alphabet_6 = [x for x in alpha_same_word_list if len(x)==7]
dictionary_output_file.write("\n 6 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_6:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 7    
alphabet_7 = [x for x in alpha_same_word_list if len(x)==8]
dictionary_output_file.write("\n 7 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_7:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 8    
alphabet_8 = [x for x in alpha_same_word_list if len(x)==9]
dictionary_output_file.write("\n 8 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_8:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 9    
alphabet_9 = [x for x in alpha_same_word_list if len(x)==10]
dictionary_output_file.write("\n 9 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_9:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 10    
alphabet_10 = [x for x in alpha_same_word_list if len(x)==11]
dictionary_output_file.write("\n 10 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_10:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 11    
alphabet_11 = [x for x in alpha_same_word_list if len(x)==12]
dictionary_output_file.write("\n 11 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_11:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 12    
alphabet_12 = [x for x in alpha_same_word_list if len(x)==13]
dictionary_output_file.write("\n 12 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_12:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 13    
alphabet_13 = [x for x in alpha_same_word_list if len(x)==14]
dictionary_output_file.write("\n 13 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_13:
    dictionary_output_file.write(word)

    
## Words With Same Starting Letter with Word length as 14    
alphabet_14 = [x for x in alpha_same_word_list if len(x)==15]
dictionary_output_file.write("\n 14 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_14:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")

    
## Words With Same Starting Letter with Word length as 15    
alphabet_15 = [x for x in alpha_same_word_list if len(x)==16]
dictionary_output_file.write("\n 15 LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
dictionary_output_file.write("===============================\n")
for word in alphabet_15:
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")
    
## Same letter Starting all Words List Write To Output File
dictionary_output_file.write("\n SAME LETTER STARTING ALL WORDS LIST \n")
dictionary_output_file.write("=============================== \n")
for word in alpha_same_word_list:
    print(word)
    dictionary_output_file.write(word)
    dictionary_output_file.write("\n")    
dictionary_output_file.close()
# Out:
# Q
#
# Q
#
# Q.
#
# Q.C.
#
# q.e.
#
# Q.E.D.
#
# Q.E.F.
#
# Q.F.
#
# q.t.
#
# q.v.
#
# QA
#
# qabbala
#
# qabbalah
#
# Qadarite
#
# Qaddafi
#
# Qaddish
#
# qadi
#
# Qadianis
#
# Qadiriya
#
# qaf
#
# qaid
#
# qaids
#
# qaimaqam
#
# Qairwan
#
# QAM
#
# qanat
#
# qanats
#
# qantar
#
# QARANC
#
# QAS
#
# qasida
#
# qasidas
#
# qat
#
# Qatar
#
# qats
#
# QB
#
# q-boat
#
# QBP
#
# QC
#
# Q-celt
#
# Q-Celtic
#
# QD
#
# QDA
#
# QDCS
#
# QE
#
# QED
#
# QEF
#
# QEI
#
# qere
#
# qeri
#
# Qeshm
#
# QET
#
# QF
#
# Q-factor
#
# Q-fever
#
# Q-group
#
# qh
#
# Qy
#
# Qiana
#
# qibla
#
# QIC
#
# QID
#
# qiyas
#
# qindar
#
# qindarka
#
# qindars
#
# qintar
#
# qintars
#
# QIS
#
# Qishm
#
# qiviut
#
# qiviuts
#
# QKt
#
# QKtP
#
# ql
#
# ql.
#
# Q-language
#
# Qld
#
# QLI
#
# QM
#
# QMC
#
# QMF
#
# QMG
#
# QMP
#
# QMS
#
# QN
#
# QNP
#
# QNS
#
# Qoheleth
#
# Qom
#
# qoph
#
# qophs
#
# QP
#
# Qq
#
# Qq.
#
# QQV
#
# QR
#
# qr.
#
# QRA
#
# QRP
#
# qrs
#
# QRSS
#
# QS
#
# q's
#
# Q-shaped
#
# Q-ship
#
# QSY
# ...
