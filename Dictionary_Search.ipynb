# %%
## Using dictionary find all the words with specific lenght for a single letter

import requests
import sys

## Retrive Dictionary data from URL
dictionary_url = "https://raw.githubusercontent.com/dwyl/english-words/master/words.txt"
dictionary_data = requests.get(dictionary_url)

## Write the dictionary data to a file
with open('C://Users//Ultimate//Desktop//Dictionary_file.txt', 'w') as file:
    file.write(dictionary_data.text)

## Read the dictionary file    
dictionary_data = open("C://Users//Ultimate//Desktop//Dictionary_file.txt","r")
dictionary_data_list = list(dictionary_data)

## Write Output to Txt File
dictionary_output_file= open("C://Users//Ultimate//Desktop//Dictionary_Same_Letter_Word.txt", "w")

## Specify the Letter You want to Search in Caps
alphabet_start_letter = "R"
alphabet_same_start=[]

## Same letter Starting all Words List
alpha_same_word_list = [x for x in dictionary_data_list if x.lower().startswith(alphabet_start_letter.lower())]

max_len = len(max(alpha_same_word_list, key=len))
min_len = len(min(alpha_same_word_list, key=len))
    
word_list = [word for word in alpha_same_word_list]
i=min_len
while(i<=max_len):
    print("\n",i-1," LETTER WORDS THAT START WITH "+"' "+alphabet_start_letter +" '"+"\n")
    print("=============================================\n")
    words =[word for word in word_list if len(word)==i]
    for word in words:
        print(word)
        word_list.remove(word)
    i+=1
print("=============================================\n")
print("Word List",word_list)
# Out:
#  1  LETTER WORDS THAT START WITH ' R '
#
# ...
#
# R
#
#
#  2  LETTER WORDS THAT START WITH ' R '
#
# ...
#
# R.
#
# RA
#
# RB
#
# RC
#
# RD
#
# RE
#
# RF
#
# rg
#
# RH
#
# RI
#
# ry
#
# RJ
#
# RL
#
# RM
#
# RN
#
# RO
#
# RP
#
# RQ
#
# RR
#
# RS
#
# RT
#
# RU
#
# RV
#
# RW
#
# RX
#
#
#  3  LETTER WORDS THAT START WITH ' R '
#
# ...
#
# R&D
#
# R/D
#
# Rab
#
# RAC
#
# RAD
#
# Rae
#
# RAF
#
# rag
#
# rah
#
# Rai
#
# Ray
#
# Raj
#
# RAM
#
# RAN
#
# RAO
#
# Rap
#
# RAR
#
# RAS
#
# rat
#
# raw
#
# rax
#
# RB-
#
# RBC
#
# RBE
#
# RBI
#
# RBT
#
# RCA
#
# RCB
#
# RCC
#
# rcd
#
# RCF
#
# RCH
#
# RCI
#
# RCL
#
# RCM
#
# RCN
#
# RCO
#
# RCP
#
# RCS
#
# RCT
#
# RCU
#
# Rd.
#
# RDA
#
# RDC
#
# RDF
#
# RDL
#
# RDM
#
# RDP
#
# RDS
#
# RDT
#
# RDX
#
# re-
#
# Re.
#
# REA
#
# Reb
#
# REC
#
# red
#
# Ree
#
# ref
#
# Reg
#
# reh
#
# rei
#
# Rey
#
# rel
#
# REM
#
# REN
#
# REO
#
# Rep
#
# req
#
# res
#
# ret
#
# Rev
#
# Rew
#
# REX
#
# RFA
#
# rfb
#
# RFC
#
# RFD
#
# RFE
#
# RFI
#
# RFP
#
# RFQ
#
# RFS
#
# RFT
#
# rfz
#
# ...
