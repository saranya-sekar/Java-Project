# %%
# importing libraries
#http://103.251.43.52/lottery/viewlotisresult.php?drawserial=72567 
#http://www.keralalotteries.com/index.php/quick-view/result

import csv
import random


Lottery_Random_No =set([])
fourth_Prize_Set = set([])

prize_number = set(list(random.sample(range(100000, 999999), 1000)))
prize_number = list(prize_number)

code_city = {'KJ':'PATTAMBI','KH':'IDUKKI','KA':'IRINJALAKUDA','KB':'MALAPPURAM','KD':'ATTINGAL','KE':'NEYYATTINKARA',
            'KF':'ERNAKULAM','KG':'GURUVAYOOR','KH':'THRISSUR','KL':'KOLLAM','KM':'PALAKKAD'}


first_prize_code, city = random.choice(list(code_city.items()))
first_prize_final = first_prize_code + " " +str(prize_number[0]) + " ("+ city +") "
print("\n\n====== 1 Prize Rs :8000000/- ======\n\n" , first_prize_final)

print("\n\n====== Cons Prize-Rs :8000/- ======\n\n")
for i in range(0,10):
    cons_prize_code, city = random.choice(list(code_city.items()))
    if(cons_prize_code != first_prize_code):
        cons_prize_final = cons_prize_code + " " +str(prize_number[0])
        print(cons_prize_final)
    
code, city = random.choice(list(code_city.items()))
second_prize_final = code + " " +str(prize_number[1]) + " ("+ city +") "
print ("\n\n====== 2nd Prize Rs :500000/- ======\n\n",second_prize_final)
        
print ("\n\n====== 3rd Prize Rs :100000/- ======\n\n")    
for i in prize_number[2:13]:
    code, city = random.choice(list(code_city.items()))
    third_prize_final = code + " " +str(i) + " ("+ city +") "
    print (third_prize_final)
    
print("\n\n FOR THE TICKETS ENDING WITH THE FOLLOWING NUMBERS")
print ("\n\n====== 4th Prize-Rs :5000/- ======\n\n")    
for i in prize_number[12:30]:
    i = int(str(i)[:-2])
    print(i)

print("\n\n====== 5th Prize-Rs :2000/-====== \n\n")
for i in prize_number[31:41]:
    i = int(str(i)[:-2])
    print(i)

print("\n\n====== 6th Prize-Rs :1000/- ======\n\n")
for i in prize_number[42:56]:
    i = int(str(i)[:-2])
    print(i)
    
print("\n\n====== 7th Prize-Rs :500/- ======\n\n")
for i in prize_number[56:136]:
    i = int(str(i)[:-2])
    print(i) 
    
print("\n\n====== 8th Prize-Rs :100/- ======\n\n")
for i in prize_number[136:760]:
    i = int(str(i)[:-2])
    print(i)
# Out:
# ====== 1 Prize Rs :8000000/- ======
#
#  KL 978944 (KOLLAM)
#
#
# ====== Cons Prize-Rs :8000/- ======
#
#
# KE 978944
# KJ 978944
# KJ 978944
# KA 978944
# KE 978944
# KG 978944
# KB 978944
# KF 978944
#
#
# ====== 2nd Prize Rs :500000/- ======
#
#  KM 421891 (PALAKKAD)
#
#
# ====== 3rd Prize Rs :100000/- ======
#
#
# KF 839684 (ERNAKULAM)
# KL 966659 (KOLLAM)
# KM 260102 (PALAKKAD)
# KG 538631 (GURUVAYOOR)
# KF 235528 (ERNAKULAM)
# KA 475145 (IRINJALAKUDA)
# KB 997385 (MALAPPURAM)
# KA 710668 (IRINJALAKUDA)
# KJ 245774 (PATTAMBI)
# KA 466965 (IRINJALAKUDA)
# KB 532503 (MALAPPURAM)
#
#
#  FOR THE TICKETS ENDING WITH THE FOLLOWING NUMBERS
#
#
# ====== 4th Prize-Rs :5000/- ======
#
#
# 5325
# 6717
# 1720
# 3727
# 9236
# 3031
# 7659
# 2314
# 6943
# 3256
# 3543
# 8069
# 6205
# 8172
# 4690
# 9298
# 9462
# 1516
#
#
# ====== 5th Prize-Rs :2000/-======
#
#
# 4711
# 8807
# 6144
# 6881
# 8131
# 9462
# 5427
# 9913
# 4055
# 3666
#
#
# ====== 6th Prize-Rs :1000/- ======
#
#
# 5038
# 6595
# 7271
# ...
